# %%
import pandas as pd

df = pd.read_csv("scraped_ebay_listings.csv.xls")

df.head()
# Out:
#   product_id                                              title condition  \
# 0      L0283  Lenovo Ideapad 320-15IKBN 6GB Used good condition      Used
# 1      L0410        Lenovo ThinkPad P51 8GB Used good condition      Used
# 2      L0583    Dell Latitude 5580 16GB Like New good condition  Like New
# 3      L0407     Dell Latitude 7480 8GB Like New good condition  Like New
# 4      L0509  Lenovo Legion Y520-15IKBN 8GB Like New good co...  Like New
#
#    resale_price   location
# 0        289.50    Chennai
# 1        962.50  Bangalore
# 2       1229.91  Bangalore
# 3       1344.00  Bangalore
# 4        919.20  Bangalore

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    200 non-null    object
#  1   title         200 non-null    object
#  2   condition     200 non-null    object
#  3   resale_price  200 non-null    float64
#  4   location      200 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 7.9+ KB

# %%
df.describe(include="all")
# Out:
#        product_id                                   title condition  \
# count         200                                     200       200
# unique        200                                     188         3
# top         L0283  HP ProBook 450 4GB Used good condition      Used
# freq            1                                       3        76
# mean          NaN                                     NaN       NaN
# std           NaN                                     NaN       NaN
# min           NaN                                     NaN       NaN
# 25%           NaN                                     NaN       NaN
# 50%           NaN                                     NaN       NaN
# 75%           NaN                                     NaN       NaN
# max           NaN                                     NaN       NaN
#
#         resale_price location
# count     200.000000      200
# unique           NaN        4
# top              NaN   Mumbai
# ...

# %%
df.isnull().sum()
# Out:
# product_id      0
# title           0
# condition       0
# resale_price    0
# location        0
# dtype: int64

# %% [raw]
# THERE ARE NO NULL VALUES IN THE DATASET

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [raw]
# NO DUPLICATE RECORDS WERE FOUND

# %% [raw]
# =============================================     END     ====================================================
